# %%
# !git clone https://github.com/shlomota/augprompt
# !pip install datasets
# !pip install transformers
# Out:
# Cloning into 'augprompt'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# Unpacking objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0

# %%
# %cd augprompt
# Out:
# /content/augprompt

# %%
# !python train_sst.py -t b -m 2 -e 10 -n 100 -f True
# Out:
# 2021-08-16 02:51:53.575162: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# started loading sst
# done loading sst
# starting load
# Using custom data configuration default-9d37732f5037cfa3
# Reusing dataset sst (../sst/default-9d37732f5037cfa3/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff)
# finished load
# Namespace(augment_type='b', epochs=10, f=True, multiplier=2, n=100)
# Loading cached shuffled indices for dataset at ../sst/default-9d37732f5037cfa3/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff/cache-b637bca08711d1d0.arrow
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# example num 0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# example num 3
# ...
